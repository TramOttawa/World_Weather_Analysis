# %%
# Import the dependencies.

import random
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6b22ee7a2c70a5895a6b88b176669c7d

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | skibbereen
# Processing Record 2 of Set 16 | bredasdorp
# Processing Record 3 of Set 16 | beloha
# Processing Record 4 of Set 16 | hilo
# Processing Record 5 of Set 16 | kruisfontein
# Processing Record 6 of Set 16 | senno
# Processing Record 7 of Set 16 | pyinmana
# Processing Record 8 of Set 16 | avarua
# Processing Record 9 of Set 16 | atlantic beach
# Processing Record 10 of Set 16 | el sauzal
# Processing Record 11 of Set 16 | saint-philippe
# Processing Record 12 of Set 16 | tuktoyaktuk
# Processing Record 13 of Set 16 | puerto ayora
# Processing Record 14 of Set 16 | kaitangata
# Processing Record 15 of Set 16 | arnedo
# Processing Record 16 of Set 16 | busselton
# Processing Record 17 of Set 16 | mehamn
# Processing Record 18 of Set 16 | rikitea
# Processing Record 19 of Set 16 | vaini
# Processing Record 20 of Set 16 | vao
# Processing Record 21 of Set 16 | georgetown
# Processing Record 22 of Set 16 | atuona
# Processing Record 23 of Set 16 | labuhan
# Processing Record 24 of Set 16 | new norfolk
# Processing Record 25 of Set 16 | linxia
# Processing Record 26 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 16 | vanimo
# Processing Record 29 of Set 16 | safaga
# Processing Record 30 of Set 16 | kaniama
# Processing Record 31 of Set 16 | olafsvik
# Processing Record 32 of Set 16 | tilichiki
# Processing Record 33 of Set 16 | san patricio
# Processing Record 34 of Set 16 | ushuaia
# Processing Record 35 of Set 16 | yellowknife
# Processing Record 36 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 16 | cidreira
# Processing Record 38 of Set 16 | pangnirtung
# Processing Record 39 of Set 16 | port lincoln
# Processing Record 40 of Set 16 | son la
# Processing Record 41 of Set 16 | kapaa
# Processing Record 42 of Set 16 | bethel
# Processing Record 43 of Set 16 | kavaratti
# Processing Record 44 of Set 16 | laela
# Processing Record 45 of Set 16 | sao miguel do araguaia
# Processing Record 46 of Set 16 | kitale
# Processing Record 47 of Set 16 | sola
# Processing Record 48 of Set 16 | shizunai
# Processing Record 49 of Set 16 | thompson
# Processing Record 50 of Set 16 | chapais
# Processing Record 1 of Set 17 | isilkul
# Processing Record 2 of Set 17 | mahebourg
# Processing Record 3 of Set 17 | jamestown
# Processing Record 4 of Set 17 | provideniya
# Processing Record 5 of Set 17 | eugene
# Processing Record 6 of Set 17 | heyang
# Processing Record 7 of Set 17 | mataura
# Processing Record 8 of Set 17 | saint-leu
# Processing Record 9 of Set 17 | namatanai
# Processing Record 10 of Set 17 | cape town
# Processing Record 11 of Set 17 | ostrovnoy
# Processing Record 12 of Set 17 | teahupoo
# Processing Record 13 of Set 17 | erzin
# Processing Record 14 of Set 17 | placido de castro
# Processing Record 15 of Set 17 | yulara
# Processing Record 16 of Set 17 | allapalli
# Processing Record 17 of Set 17 | kyzyl-suu
# Processing Record 18 of Set 17 | hasaki
# Processing Record 19 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 17 | saint stephen
# Processing Record 21 of Set 17 | bluff
# Processing Record 22 of Set 17 | katsuura
# Processing Record 23 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 17 | bambous virieux
# Processing Record 25 of Set 17 | luderitz
# Processing Record 26 of Set 17 | ribeira grande
# Processing Record 27 of Set 17 | challapata
# Processing Record 28 of Set 17 | debre birhan
# Processing Record 29 of Set 17 | albany
# Processing Record 30 of Set 17 | mayo
# Processing Record 31 of Set 17 | ponta do sol
# Processing Record 32 of Set 17 | torbay
# Processing Record 33 of Set 17 | punta arenas
# Processing Record 34 of Set 17 | guerrero negro
# Processing Record 35 of Set 17 | santa maria
# Processing Record 36 of Set 17 | gilgit
# Processing Record 37 of Set 17 | chokurdakh
# Processing Record 38 of Set 17 | hofn
# Processing Record 39 of Set 17 | butaritari
# Processing Record 40 of Set 17 | los algarrobos
# Processing Record 41 of Set 17 | lodwar
# Processing Record 42 of Set 17 | lozova
# Processing Record 43 of Set 17 | gat
# Processing Record 44 of Set 17 | misratah
# Processing Record 45 of Set 17 | huilong
# Processing Record 46 of Set 17 | bundaberg
# Processing Record 47 of Set 17 | ponta delgada
# Processing Record 48 of Set 17 | sao joao da barra
# Processing Record 49 of Set 17 | pontes e lacerda
# Processing Record 50 of Set 17 | deputatskiy
# Processing Record 1 of Set 18 | beringovskiy
# Processing Record 2 of Set 18 | champerico
# Processing Record 3 of Set 18 | port alfred
# Processing Record 4 of Set 18 | dunedin
# Processing Record 5 of Set 18 | solnechnyy
# Processing Record 6 of Set 18 | leshukonskoye
# Processing Record 7 of Set 18 | tasiilaq
# Processing Record 8 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 18 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 18 | castro
# Processing Record 11 of Set 18 | san isidro
# Processing Record 12 of Set 18 | longyearbyen
# Processing Record 13 of Set 18 | valsad
# Processing Record 14 of Set 18 | hobart
# Processing Record 15 of Set 18 | poum
# Processing Record 16 of Set 18 | arraial do cabo
# Processing Record 17 of Set 18 | castelo do piaui
# Processing Record 18 of Set 18 | ahipara
# Processing Record 19 of Set 18 | tynda
# Processing Record 20 of Set 18 | port macquarie
# Processing Record 21 of Set 18 | port hawkesbury
# Processing Record 22 of Set 18 | barrow
# Processing Record 23 of Set 18 | kodiak
# Processing Record 24 of Set 18 | faanui
# Processing Record 25 of Set 18 | niquelandia
# Processing Record 26 of Set 18 | acarau
# Processing Record 27 of Set 18 | teruel
# Processing Record 28 of Set 18 | sorong
# Processing Record 29 of Set 18 | oinoussai
# City not found. Skipping...
# Processing Record 30 of Set 18 | airai
# Processing Record 31 of Set 18 | mikuni
# Processing Record 32 of Set 18 | yarmouth
# Processing Record 33 of Set 18 | havelock
# Processing Record 34 of Set 18 | qaanaaq
# Processing Record 35 of Set 18 | east london
# Processing Record 36 of Set 18 | nianzishan
# Processing Record 37 of Set 18 | nome
# Processing Record 38 of Set 18 | chimoio
# Processing Record 39 of Set 18 | aswan
# Processing Record 40 of Set 18 | narsaq
# Processing Record 41 of Set 18 | saldanha
# Processing Record 42 of Set 18 | oussouye
# Processing Record 43 of Set 18 | srednekolymsk
# Processing Record 44 of Set 18 | rottingdean
# Processing Record 45 of Set 18 | palmer
# Processing Record 46 of Set 18 | constitucion
# Processing Record 47 of Set 18 | taltal
# Processing Record 48 of Set 18 | nikolskoye
# Processing Record 49 of Set 18 | fayaoue
# Processing Record 50 of Set 18 | walvis bay
# Processing Record 1 of Set 19 | yar-sale
# Processing Record 2 of Set 19 | mecca
# Processing Record 3 of Set 19 | anloga
# Processing Record 4 of Set 19 | angoche
# Processing Record 5 of Set 19 | chico
# Processing Record 6 of Set 19 | bowen
# Processing Record 7 of Set 19 | tarakan
# Processing Record 8 of Set 19 | cherskiy
# Processing Record 9 of Set 19 | talcahuano
# Processing Record 10 of Set 19 | pinega
# Processing Record 11 of Set 19 | shingu
# Processing Record 12 of Set 19 | bathsheba
# Processing Record 13 of Set 19 | alyangula
# Processing Record 14 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 19 | nanga eboko
# Processing Record 16 of Set 19 | paciran
# Processing Record 17 of Set 19 | lushunkou
# City not found. Skipping...
# Processing Record 18 of Set 19 | kibala
# Processing Record 19 of Set 19 | camacupa
# Processing Record 20 of Set 19 | sabang
# Processing Record 21 of Set 19 | machachi
# Processing Record 22 of Set 19 | yola
# Processing Record 23 of Set 19 | atar
# Processing Record 24 of Set 19 | kupang
# Processing Record 25 of Set 19 | cururupu
# Processing Record 26 of Set 19 | mount isa
# Processing Record 27 of Set 19 | port hardy
# Processing Record 28 of Set 19 | nadym
# Processing Record 29 of Set 19 | norman wells
# Processing Record 30 of Set 19 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 19 | albion
# Processing Record 32 of Set 19 | christchurch
# Processing Record 33 of Set 19 | gornyak
# Processing Record 34 of Set 19 | ancud
# Processing Record 35 of Set 19 | isabela
# Processing Record 36 of Set 19 | char bhadrasan
# Processing Record 37 of Set 19 | boddam
# Processing Record 38 of Set 19 | anda
# Processing Record 39 of Set 19 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 19 | manjacaze
# Processing Record 41 of Set 19 | kirakira
# Processing Record 42 of Set 19 | pevek
# Processing Record 43 of Set 19 | wollongong
# Processing Record 44 of Set 19 | godda
# Processing Record 45 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 19 | comodoro rivadavia
# Processing Record 47 of Set 19 | rafraf
# Processing Record 48 of Set 19 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 19 | lorengau
# Processing Record 50 of Set 19 | victoria
# Processing Record 1 of Set 20 | kalvarija
# Processing Record 2 of Set 20 | elizabeth city
# Processing Record 3 of Set 20 | bongaree
# Processing Record 4 of Set 20 | tukrah
# Processing Record 5 of Set 20 | kandrian
# Processing Record 6 of Set 20 | cabedelo
# Processing Record 7 of Set 20 | wanparti
# Processing Record 8 of Set 20 | kudat
# Processing Record 9 of Set 20 | los llanos de aridane
# Processing Record 10 of Set 20 | qiongshan
# Processing Record 11 of Set 20 | yerbogachen
# Processing Record 12 of Set 20 | tiksi
# Processing Record 13 of Set 20 | beitbridge
# Processing Record 14 of Set 20 | baykit
# Processing Record 15 of Set 20 | bourg-en-bresse
# Processing Record 16 of Set 20 | ibra
# Processing Record 17 of Set 20 | saint george
# Processing Record 18 of Set 20 | mogadishu
# Processing Record 19 of Set 20 | khatanga
# Processing Record 20 of Set 20 | lompoc
# Processing Record 21 of Set 20 | kudahuvadhoo
# Processing Record 22 of Set 20 | meulaboh
# Processing Record 23 of Set 20 | prinos
# Processing Record 24 of Set 20 | xai-xai
# Processing Record 25 of Set 20 | stanislav
# Processing Record 26 of Set 20 | north bend
# Processing Record 27 of Set 20 | westport
# Processing Record 28 of Set 20 | la mira
# Processing Record 29 of Set 20 | bawku
# Processing Record 30 of Set 20 | talnakh
# Processing Record 31 of Set 20 | kavieng
# Processing Record 32 of Set 20 | hermanus
# Processing Record 33 of Set 20 | seddon
# Processing Record 34 of Set 20 | orimattila
# Processing Record 35 of Set 20 | winnemucca
# Processing Record 36 of Set 20 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 20 | iqaluit
# Processing Record 38 of Set 20 | la seyne-sur-mer
# Processing Record 39 of Set 20 | guiratinga
# Processing Record 40 of Set 20 | shilong
# Processing Record 41 of Set 20 | rock sound
# Processing Record 42 of Set 20 | nanortalik
# Processing Record 43 of Set 20 | lazaro cardenas
# Processing Record 44 of Set 20 | alice springs
# Processing Record 45 of Set 20 | muros
# Processing Record 46 of Set 20 | richards bay
# Processing Record 47 of Set 20 | tura
# Processing Record 48 of Set 20 | lucapa
# Processing Record 49 of Set 20 | polyarnyy
# Processing Record 50 of Set 20 | puerto del rosario
# Processing Record 1 of Set 21 | tual
# Processing Record 2 of Set 21 | kozhva
# Processing Record 3 of Set 21 | bar-le-duc
# Processing Record 4 of Set 21 | ucluelet
# Processing Record 5 of Set 21 | axim
# Processing Record 6 of Set 21 | port elizabeth
# Processing Record 7 of Set 21 | mayma
# Processing Record 8 of Set 21 | gamboula
# Processing Record 9 of Set 21 | ilinskiy
# Processing Record 10 of Set 21 | ilulissat
# Processing Record 11 of Set 21 | agadez
# Processing Record 12 of Set 21 | anchorage
# Processing Record 13 of Set 21 | port blair
# Processing Record 14 of Set 21 | urumqi
# Processing Record 15 of Set 21 | isangel
# Processing Record 16 of Set 21 | dikson
# Processing Record 17 of Set 21 | thinadhoo
# Processing Record 18 of Set 21 | khor
# Processing Record 19 of Set 21 | maragogi
# Processing Record 20 of Set 21 | olds
# Processing Record 21 of Set 21 | fortuna
# Processing Record 22 of Set 21 | goderich
# Processing Record 23 of Set 21 | lebyazhye
# Processing Record 24 of Set 21 | hithadhoo
# Processing Record 25 of Set 21 | pilar
# Processing Record 26 of Set 21 | inhambane
# Processing Record 27 of Set 21 | lydenburg
# Processing Record 28 of Set 21 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 21 | luganville
# Processing Record 30 of Set 21 | port hueneme
# Processing Record 31 of Set 21 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 21 | ambalavao
# Processing Record 33 of Set 21 | mkushi
# Processing Record 34 of Set 21 | jiquilisco
# Processing Record 35 of Set 21 | tshane
# Processing Record 36 of Set 21 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 21 | camacha
# Processing Record 38 of Set 21 | sao filipe
# Processing Record 39 of Set 21 | naze
# Processing Record 40 of Set 21 | mandalgovi
# Processing Record 41 of Set 21 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 21 | ardino
# Processing Record 43 of Set 21 | bartica
# Processing Record 44 of Set 21 | bulungu
# Processing Record 45 of Set 21 | salisbury
# Processing Record 46 of Set 21 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 21 | gaoyou
# Processing Record 48 of Set 21 | timmins
# Processing Record 49 of Set 21 | markova
# Processing Record 50 of Set 21 | port hedland
# Processing Record 1 of Set 22 | alugan
# Processing Record 2 of Set 22 | yibin
# Processing Record 3 of Set 22 | rundu
# Processing Record 4 of Set 22 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 22 | sarakhs
# Processing Record 6 of Set 22 | kalabo
# Processing Record 7 of Set 22 | teacapan
# Processing Record 8 of Set 22 | pisco
# Processing Record 9 of Set 22 | arti
# Processing Record 10 of Set 22 | garowe
# Processing Record 11 of Set 22 | minudasht
# Processing Record 12 of Set 22 | abbeville
# Processing Record 13 of Set 22 | lixourion
# Processing Record 14 of Set 22 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 22 | grand gaube
# Processing Record 16 of Set 22 | aasiaat
# Processing Record 17 of Set 22 | cabo san lucas
# Processing Record 18 of Set 22 | hovd
# Processing Record 19 of Set 22 | callaway
# Processing Record 20 of Set 22 | lebu
# Processing Record 21 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 22 | jangipur
# Processing Record 23 of Set 22 | chuy
# Processing Record 24 of Set 22 | sao geraldo do araguaia
# Processing Record 25 of Set 22 | monte alegre
# Processing Record 26 of Set 22 | flinders
# Processing Record 27 of Set 22 | roebourne
# Processing Record 28 of Set 22 | kolyvan
# Processing Record 29 of Set 22 | parry sound
# Processing Record 30 of Set 22 | nouadhibou
# Processing Record 31 of Set 22 | barra patuca
# Processing Record 32 of Set 22 | terenga
# City not found. Skipping...
# Processing Record 33 of Set 22 | daru
# Processing Record 34 of Set 22 | taixing
# Processing Record 35 of Set 22 | tohana
# Processing Record 36 of Set 22 | grand island
# Processing Record 37 of Set 22 | margate
# Processing Record 38 of Set 22 | chato
# Processing Record 39 of Set 22 | san-pedro
# Processing Record 40 of Set 22 | ixtapa
# Processing Record 41 of Set 22 | samana
# Processing Record 42 of Set 22 | pekalongan
# Processing Record 43 of Set 22 | kimbe
# Processing Record 44 of Set 22 | togitsu
# Processing Record 45 of Set 22 | pafos
# Processing Record 46 of Set 22 | hastings
# Processing Record 47 of Set 22 | upernavik
# Processing Record 48 of Set 22 | karpathos
# Processing Record 49 of Set 22 | la salle
# Processing Record 50 of Set 22 | nueva gerona
# Processing Record 1 of Set 23 | nefteyugansk
# Processing Record 2 of Set 23 | varhaug
# Processing Record 3 of Set 23 | mtambile
# Processing Record 4 of Set 23 | smoky lake
# Processing Record 5 of Set 23 | requena
# Processing Record 6 of Set 23 | khovu-aksy
# Processing Record 7 of Set 23 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 23 | trincomalee
# Processing Record 9 of Set 23 | nylstroom
# City not found. Skipping...
# Processing Record 10 of Set 23 | wonthaggi
# Processing Record 11 of Set 23 | adrar
# Processing Record 12 of Set 23 | marsciano
# Processing Record 13 of Set 23 | namibe
# Processing Record 14 of Set 23 | grindavik
# Processing Record 15 of Set 23 | dingle
# Processing Record 16 of Set 23 | cockburn town
# Processing Record 17 of Set 23 | berlevag
# Processing Record 18 of Set 23 | otane
# Processing Record 19 of Set 23 | alofi
# Processing Record 20 of Set 23 | kolo
# Processing Record 21 of Set 23 | lagoa
# Processing Record 22 of Set 23 | saint-francois
# Processing Record 23 of Set 23 | nandi hills
# Processing Record 24 of Set 23 | belfast
# Processing Record 25 of Set 23 | fairbanks
# Processing Record 26 of Set 23 | bauru
# Processing Record 27 of Set 23 | rehoboth
# Processing Record 28 of Set 23 | carnarvon
# Processing Record 29 of Set 23 | kalmunai
# Processing Record 30 of Set 23 | amahai
# Processing Record 31 of Set 23 | mar del plata
# Processing Record 32 of Set 23 | suileng
# Processing Record 33 of Set 23 | ustka
# Processing Record 34 of Set 23 | saint anthony
# Processing Record 35 of Set 23 | ginda
# Processing Record 36 of Set 23 | prado
# Processing Record 37 of Set 23 | bela palanka
# Processing Record 38 of Set 23 | molepolole
# Processing Record 39 of Set 23 | chino valley
# Processing Record 40 of Set 23 | zhigansk
# Processing Record 41 of Set 23 | keetmanshoop
# Processing Record 42 of Set 23 | bahia blanca
# Processing Record 43 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 23 | san cristobal
# Processing Record 45 of Set 23 | prince albert
# Processing Record 46 of Set 23 | nishihara
# Processing Record 47 of Set 23 | ossora
# Processing Record 48 of Set 23 | siderno
# Processing Record 49 of Set 23 | marsabit
# Processing Record 50 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 24 | santa cruz
# Processing Record 2 of Set 24 | barcelos
# Processing Record 3 of Set 24 | mareeba
# Processing Record 4 of Set 24 | lima
# Processing Record 5 of Set 24 | mets masrik
# Processing Record 6 of Set 24 | karratha
# Processing Record 7 of Set 24 | lahan
# Processing Record 8 of Set 24 | aviles
# Processing Record 9 of Set 24 | tank
# Processing Record 10 of Set 24 | touros
# Processing Record 11 of Set 24 | ambovombe
# Processing Record 12 of Set 24 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 24 | liman
# Processing Record 14 of Set 24 | magadan
# Processing Record 15 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 24 | kyakhta
# Processing Record 17 of Set 24 | svetlogorsk
# Processing Record 18 of Set 24 | khammam
# Processing Record 19 of Set 24 | krasnofarfornyy
# Processing Record 20 of Set 24 | zhangjiakou
# Processing Record 21 of Set 24 | barra do corda
# Processing Record 22 of Set 24 | tari
# Processing Record 23 of Set 24 | sorland
# Processing Record 24 of Set 24 | play cu
# City not found. Skipping...
# Processing Record 25 of Set 24 | springbok
# Processing Record 26 of Set 24 | taseyevo
# Processing Record 27 of Set 24 | otaru
# Processing Record 28 of Set 24 | riberalta
# Processing Record 29 of Set 24 | huarmey
# Processing Record 30 of Set 24 | saint-joseph
# Processing Record 31 of Set 24 | aklavik
# Processing Record 32 of Set 24 | araouane
# Processing Record 33 of Set 24 | skaerbaek
# Processing Record 34 of Set 24 | tuatapere
# Processing Record 35 of Set 24 | bubaque
# Processing Record 36 of Set 24 | kahului
# Processing Record 37 of Set 24 | oranjemund
# Processing Record 38 of Set 24 | tateyama
# Processing Record 39 of Set 24 | candawaga
# City not found. Skipping...
# Processing Record 40 of Set 24 | belaya gora
# Processing Record 41 of Set 24 | nyimba
# Processing Record 42 of Set 24 | oktyabrskoye
# Processing Record 43 of Set 24 | umm lajj
# Processing Record 44 of Set 24 | komsomolskiy
# Processing Record 45 of Set 24 | garmsar
# Processing Record 46 of Set 24 | verkhnevilyuysk
# Processing Record 47 of Set 24 | mopipi
# Processing Record 48 of Set 24 | ladario
# Processing Record 49 of Set 24 | mezen
# Processing Record 50 of Set 24 | bandarbeyla
# Processing Record 1 of Set 25 | gambela
# Processing Record 2 of Set 25 | kitob
# Processing Record 3 of Set 25 | tshikapa
# Processing Record 4 of Set 25 | krasnousolskiy
# City not found. Skipping...
# Processing Record 5 of Set 25 | severo-kurilsk
# Processing Record 6 of Set 25 | lata
# Processing Record 7 of Set 25 | shaoyang
# Processing Record 8 of Set 25 | filadelfia
# Processing Record 9 of Set 25 | cayenne
# Processing Record 10 of Set 25 | henties bay
# Processing Record 11 of Set 25 | praia da vitoria
# Processing Record 12 of Set 25 | jalu
# Processing Record 13 of Set 25 | mizpe ramon
# City not found. Skipping...
# Processing Record 14 of Set 25 | namanga
# Processing Record 15 of Set 25 | fougamou
# Processing Record 16 of Set 25 | tommot
# Processing Record 17 of Set 25 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 25 | husavik
# Processing Record 19 of Set 25 | doha
# Processing Record 20 of Set 25 | van buren
# Processing Record 21 of Set 25 | salalah
# Processing Record 22 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 25 | carmo do cajuru
# Processing Record 24 of Set 25 | kununurra
# Processing Record 25 of Set 25 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 25 | san quintin
# Processing Record 27 of Set 25 | langres
# Processing Record 28 of Set 25 | leningradskiy
# Processing Record 29 of Set 25 | rafai
# Processing Record 30 of Set 25 | krotoszyn
# Processing Record 31 of Set 25 | hirara
# Processing Record 32 of Set 25 | puqi
# Processing Record 33 of Set 25 | andenes
# Processing Record 34 of Set 25 | mulchen
# Processing Record 35 of Set 25 | abnub
# Processing Record 36 of Set 25 | evensk
# Processing Record 37 of Set 25 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 25 | tezu
# Processing Record 39 of Set 25 | malakal
# Processing Record 40 of Set 25 | miraflores
# Processing Record 41 of Set 25 | bethanien
# Processing Record 42 of Set 25 | korla
# Processing Record 43 of Set 25 | nuuk
# Processing Record 44 of Set 25 | pochutla
# Processing Record 45 of Set 25 | concordia
# Processing Record 46 of Set 25 | shanghai
# Processing Record 47 of Set 25 | clemencia
# Processing Record 48 of Set 25 | abha
# Processing Record 49 of Set 25 | coari
# Processing Record 50 of Set 25 | maykor
# Processing Record 1 of Set 26 | suba
# Processing Record 2 of Set 26 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 26 | beyneu
# Processing Record 4 of Set 26 | dubbo
# Processing Record 5 of Set 26 | shaunavon
# Processing Record 6 of Set 26 | saint-paul
# Processing Record 7 of Set 26 | salina cruz
# Processing Record 8 of Set 26 | hokitika
# Processing Record 9 of Set 26 | cap-aux-meules
# Processing Record 10 of Set 26 | kotido
# Processing Record 11 of Set 26 | mombetsu
# Processing Record 12 of Set 26 | bilma
# Processing Record 13 of Set 26 | obo
# Processing Record 14 of Set 26 | dharan
# Processing Record 15 of Set 26 | pecos
# Processing Record 16 of Set 26 | bengkulu
# Processing Record 17 of Set 26 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 26 | iskateley
# Processing Record 19 of Set 26 | sujiatun
# Processing Record 20 of Set 26 | grenville
# Processing Record 21 of Set 26 | nabire
# Processing Record 22 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 26 | puerto madryn
# Processing Record 24 of Set 26 | baiyin
# Processing Record 25 of Set 26 | capitao poco
# Processing Record 26 of Set 26 | saint-pierre
# Processing Record 27 of Set 26 | guymon
# Processing Record 28 of Set 26 | mongoumba
# Processing Record 29 of Set 26 | pemangkat
# Processing Record 30 of Set 26 | sioux lookout
# Processing Record 31 of Set 26 | waingapu
# Processing Record 32 of Set 26 | papara
# Processing Record 33 of Set 26 | dongsheng
# Processing Record 34 of Set 26 | ayagoz
# Processing Record 35 of Set 26 | maniitsoq
# Processing Record 36 of Set 26 | salinopolis
# Processing Record 37 of Set 26 | krapivinskiy
# Processing Record 38 of Set 26 | green valley
# Processing Record 39 of Set 26 | geraldton
# Processing Record 40 of Set 26 | araguatins
# City not found. Skipping...
# Processing Record 41 of Set 26 | marktoberdorf
# Processing Record 42 of Set 26 | faya
# Processing Record 43 of Set 26 | sechura
# Processing Record 44 of Set 26 | coyah
# Processing Record 45 of Set 26 | hobyo
# Processing Record 46 of Set 26 | marsa matruh
# Processing Record 47 of Set 26 | hambantota
# Processing Record 48 of Set 26 | sistranda
# Processing Record 49 of Set 26 | jurm
# Processing Record 50 of Set 26 | shimoda
# Processing Record 1 of Set 27 | pahrump
# Processing Record 2 of Set 27 | esso
# Processing Record 3 of Set 27 | redding
# Processing Record 4 of Set 27 | kieta
# Processing Record 5 of Set 27 | chernyshevskiy
# Processing Record 6 of Set 27 | sukumo
# Processing Record 7 of Set 27 | coihaique
# Processing Record 8 of Set 27 | isiro
# Processing Record 9 of Set 27 | chipinge
# Processing Record 10 of Set 27 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 27 | passi
# Processing Record 12 of Set 27 | half moon bay
# Processing Record 13 of Set 27 | rocha
# Processing Record 14 of Set 27 | elliot lake
# Processing Record 15 of Set 27 | ashoknagar
# Processing Record 16 of Set 27 | malanje
# Processing Record 17 of Set 27 | zaysan
# Processing Record 18 of Set 27 | clyde river
# Processing Record 19 of Set 27 | saint-augustin
# Processing Record 20 of Set 27 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 27 | jiayuguan
# Processing Record 22 of Set 27 | ostrow mazowiecka
# Processing Record 23 of Set 27 | amberley
# Processing Record 24 of Set 27 | shahr-e babak
# Processing Record 25 of Set 27 | labutta
# City not found. Skipping...
# Processing Record 26 of Set 27 | souillac
# Processing Record 27 of Set 27 | moron
# Processing Record 28 of Set 27 | aykhal
# Processing Record 29 of Set 27 | sikonge
# Processing Record 30 of Set 27 | marzuq
# Processing Record 31 of Set 27 | dunkwa
# Processing Record 32 of Set 27 | hamilton
# Processing Record 33 of Set 27 | nikolsk
# Processing Record 34 of Set 27 | north myrtle beach
# Processing Record 35 of Set 27 | vaovai
# City not found. Skipping...
# Processing Record 36 of Set 27 | salgueiro
# Processing Record 37 of Set 27 | sao gabriel da cachoeira
# Processing Record 38 of Set 27 | akdepe
# Processing Record 39 of Set 27 | acapulco
# Processing Record 40 of Set 27 | webuye
# Processing Record 41 of Set 27 | tres picos
# Processing Record 42 of Set 27 | usinsk
# Processing Record 43 of Set 27 | vardo
# Processing Record 44 of Set 27 | katsiveli
# City not found. Skipping...
# Processing Record 45 of Set 27 | waipawa
# Processing Record 46 of Set 27 | ayr
# Processing Record 47 of Set 27 | paamiut
# Processing Record 48 of Set 27 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 27 | north platte
# Processing Record 50 of Set 27 | sabzevar
# Processing Record 1 of Set 28 | qaqortoq
# Processing Record 2 of Set 28 | orbetello
# Processing Record 3 of Set 28 | mackenzie
# Processing Record 4 of Set 28 | sampit
# Processing Record 5 of Set 28 | gamba
# Processing Record 6 of Set 28 | fengzhen
# Processing Record 7 of Set 28 | klyuchi
# Processing Record 8 of Set 28 | nakusp
# Processing Record 9 of Set 28 | vila velha
# Processing Record 10 of Set 28 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 28 | kisesa
# Processing Record 12 of Set 28 | hammerfest
# Processing Record 13 of Set 28 | najran
# Processing Record 14 of Set 28 | san policarpo
# Processing Record 15 of Set 28 | bagotville
# Processing Record 16 of Set 28 | nizwa
# Processing Record 17 of Set 28 | dudinka
# Processing Record 18 of Set 28 | laurel
# Processing Record 19 of Set 28 | bukama
# Processing Record 20 of Set 28 | te anau
# Processing Record 21 of Set 28 | yangambi
# Processing Record 22 of Set 28 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 28 | guthrie
# Processing Record 24 of Set 28 | eyrarbakki
# Processing Record 25 of Set 28 | klaksvik
# Processing Record 26 of Set 28 | biak
# Processing Record 27 of Set 28 | ugoofaaru
# Processing Record 28 of Set 28 | nisia floresta
# Processing Record 29 of Set 28 | bintulu
# Processing Record 30 of Set 28 | twentynine palms
# Processing Record 31 of Set 28 | north las vegas
# Processing Record 32 of Set 28 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 28 | vvedenskoye
# Processing Record 34 of Set 28 | semirom
# Processing Record 35 of Set 28 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 28 | gboko
# Processing Record 37 of Set 28 | peniche
# Processing Record 38 of Set 28 | arrecife
# Processing Record 39 of Set 28 | kenai
# Processing Record 40 of Set 28 | krasnoshchekovo
# Processing Record 41 of Set 28 | orlik
# Processing Record 42 of Set 28 | linhares
# Processing Record 43 of Set 28 | westpunt
# City not found. Skipping...
# Processing Record 44 of Set 28 | kemijarvi
# Processing Record 45 of Set 28 | ballina
# Processing Record 46 of Set 28 | taksimo
# Processing Record 47 of Set 28 | pitimbu
# Processing Record 48 of Set 28 | ndioum
# Processing Record 49 of Set 28 | abu samrah
# Processing Record 50 of Set 28 | sandwick
# Processing Record 1 of Set 29 | nago
# Processing Record 2 of Set 29 | acuitzio
# Processing Record 3 of Set 29 | noumea
# Processing Record 4 of Set 29 | tecoanapa
# Processing Record 5 of Set 29 | las margaritas
# Processing Record 6 of Set 29 | asfi
# Processing Record 7 of Set 29 | don sak
# Processing Record 8 of Set 29 | dalvik
# Processing Record 9 of Set 29 | havoysund
# Processing Record 10 of Set 29 | lodja
# Processing Record 11 of Set 29 | morondava
# Processing Record 12 of Set 29 | esmeraldas
# Processing Record 13 of Set 29 | sumkino
# Processing Record 14 of Set 29 | huazolotitlan
# City not found. Skipping...
# Processing Record 15 of Set 29 | nepa nagar
# Processing Record 16 of Set 29 | chardara
# Processing Record 17 of Set 29 | peterongan
# Processing Record 18 of Set 29 | zheleznodorozhnyy
# Processing Record 19 of Set 29 | arman
# Processing Record 20 of Set 29 | raudeberg
# Processing Record 21 of Set 29 | zhiryatino
# Processing Record 22 of Set 29 | sahrak
# City not found. Skipping...
# Processing Record 23 of Set 29 | crotone
# Processing Record 24 of Set 29 | caravelas
# Processing Record 25 of Set 29 | avera
# Processing Record 26 of Set 29 | shimanovsk
# Processing Record 27 of Set 29 | smithers
# Processing Record 28 of Set 29 | vetralla
# Processing Record 29 of Set 29 | bonfim
# Processing Record 30 of Set 29 | batemans bay
# Processing Record 31 of Set 29 | kenora
# Processing Record 32 of Set 29 | umm kaddadah
# Processing Record 33 of Set 29 | holland
# Processing Record 34 of Set 29 | akhmeta
# Processing Record 35 of Set 29 | oltu
# Processing Record 36 of Set 29 | suleja
# Processing Record 37 of Set 29 | motril
# Processing Record 38 of Set 29 | meadow lake
# Processing Record 39 of Set 29 | buin
# Processing Record 40 of Set 29 | la rioja
# Processing Record 41 of Set 29 | male
# Processing Record 42 of Set 29 | port-cartier
# Processing Record 43 of Set 29 | warrington
# Processing Record 44 of Set 29 | ekhabi
# Processing Record 45 of Set 29 | tiarei
# Processing Record 46 of Set 29 | plettenberg bay
# Processing Record 47 of Set 29 | vila franca do campo
# Processing Record 48 of Set 29 | bonavista
# Processing Record 49 of Set 29 | punta alta
# Processing Record 50 of Set 29 | gimli
# Processing Record 1 of Set 30 | lithgow
# Processing Record 2 of Set 30 | antalaha
# Processing Record 3 of Set 30 | omsukchan
# Processing Record 4 of Set 30 | svetlyy
# Processing Record 5 of Set 30 | esperance
# Processing Record 6 of Set 30 | narsingdi
# Processing Record 7 of Set 30 | sinnai
# Processing Record 8 of Set 30 | lagunas
# Processing Record 9 of Set 30 | pacific grove
# Processing Record 10 of Set 30 | gurupi
# Processing Record 11 of Set 30 | nieuwpoort
# Processing Record 12 of Set 30 | ban nahin
# Processing Record 13 of Set 30 | lucena
# Processing Record 14 of Set 30 | college
# Processing Record 15 of Set 30 | sakakah
# Processing Record 16 of Set 30 | nara
# Processing Record 17 of Set 30 | seredeyskiy
# Processing Record 18 of Set 30 | riaba
# City not found. Skipping...
# Processing Record 19 of Set 30 | prince rupert
# Processing Record 20 of Set 30 | coruripe
# Processing Record 21 of Set 30 | mantua
# Processing Record 22 of Set 30 | tagusao
# Processing Record 23 of Set 30 | lehi
# Processing Record 24 of Set 30 | payakumbuh
# Processing Record 25 of Set 30 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 30 | nantucket
# Processing Record 27 of Set 30 | jacareacanga
# Processing Record 28 of Set 30 | amapa
# Processing Record 29 of Set 30 | dicabisagan
# Processing Record 30 of Set 30 | kaeo
# Processing Record 31 of Set 30 | khani
# Processing Record 32 of Set 30 | barabinsk
# Processing Record 33 of Set 30 | saskylakh
# Processing Record 34 of Set 30 | kawana waters
# City not found. Skipping...
# Processing Record 35 of Set 30 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 30 | boissevain
# Processing Record 37 of Set 30 | necochea
# Processing Record 38 of Set 30 | thanh hoa
# Processing Record 39 of Set 30 | barranca
# Processing Record 40 of Set 30 | morehead
# Processing Record 41 of Set 30 | anadyr
# Processing Record 42 of Set 30 | kokoda
# Processing Record 43 of Set 30 | lingao
# Processing Record 44 of Set 30 | novokizhinginsk
# Processing Record 45 of Set 30 | dolores
# Processing Record 46 of Set 30 | tonj
# Processing Record 47 of Set 30 | shinuhayr
# Processing Record 48 of Set 30 | miranorte
# City not found. Skipping...
# Processing Record 49 of Set 30 | talawdi
# City not found. Skipping...
# Processing Record 50 of Set 30 | kachug
# Processing Record 1 of Set 31 | tiznit
# Processing Record 2 of Set 31 | tharad
# Processing Record 3 of Set 31 | abu kamal
# Processing Record 4 of Set 31 | aberdeen
# Processing Record 5 of Set 31 | mpika
# Processing Record 6 of Set 31 | mae hong son
# Processing Record 7 of Set 31 | pamekasan
# Processing Record 8 of Set 31 | washougal
# Processing Record 9 of Set 31 | caraguatatuba
# Processing Record 10 of Set 31 | tolaga bay
# Processing Record 11 of Set 31 | broken hill
# Processing Record 12 of Set 31 | nebolchi
# Processing Record 13 of Set 31 | metro
# Processing Record 14 of Set 31 | singuilucan
# Processing Record 15 of Set 31 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 16 of Set 31 | hualmay
# Processing Record 17 of Set 31 | vargashi
# Processing Record 18 of Set 31 | sungaipenuh
# Processing Record 19 of Set 31 | samarai
# Processing Record 20 of Set 31 | sur
# Processing Record 21 of Set 31 | la ronge
# Processing Record 22 of Set 31 | lumut
# Processing Record 23 of Set 31 | tall kayf
# Processing Record 24 of Set 31 | tessalit
# Processing Record 25 of Set 31 | ahuimanu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# Convert the array of dictionaries to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Skibbereen      IE  51.5500   -9.2667     50.11        83         100
# 1    Bredasdorp      ZA -34.5322   20.0403     59.72        87          46
# 2        Beloha      MG -25.1667   45.0500     73.27        81          94
# 3          Hilo      US  19.7297 -155.0900     74.93        76           0
# 4  Kruisfontein      ZA -34.0033   24.7314     68.09        37         100
#
#    Wind Speed Current Description
# 0       15.41       moderate rain
# 1        3.80    scattered clouds
# 2       16.22     overcast clouds
# 3        6.91           clear sky
# 4        7.49     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
